# %% [markdown]
# **Load data**

# %% [markdown]
# <a href="https://colab.research.google.com/github/Blistt/bp-recommender/blob/Romasa/BP_Recommendation_system.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
path = 'data/'
baseline = pd.read_csv(path + 'baseline.csv')
augmented_k = pd.read_csv(path + 'augmented_k.csv')
augmented_inter = pd.read_csv(path + 'augmented_inter.csv')
augmented_intra = pd.read_csv(path + 'augmented_intra.csv')

# %%
from bp_predictor import BloodPresurePredictor
from utils import log_exp

def experiment(dataset, model, ntrees, N, key, target, double_run=False, log_path='', bootstrap_iter=0, bootstrap_size=0.8, aug='None'):
    # First run with all features (either bootstrapped or not)
    bp_predictor = BloodPresurePredictor(model, ntrees)
    if bootstrap_iter > 0:
        bp_predictor.bootstrap(dataset, bootstrap_iter, bootstrap_size)
    else:
        bp_predictor.predict(dataset)
    log_exp(log_path, bp_predictor, aug='None', N=N, double=False, bootstrap=(bootstrap_iter>0))     # log results
    
    # Second run with top N features
    top_n = list(bp_predictor.feature_importances.keys())[:N]       # get top N features from dict 
    cols = key + top_n + target                                     # add key and target columns
    bp_predictor.predict(dataset[cols])                             # predict with top N features
    log_exp(log_path, bp_predictor, aug='None', N=N, double=True, bootstrap=(bootstrap_iter>0))   # log results

# %%
from bp_predictor import BloodPresurePredictor
from utils import log_exp, get_unique_healthCodes

def personalised_experiment(dataset, model, ntrees, N, key, target, double_run=False, log_path='', bootstrap_iter=0, bootstrap_size=0.8, aug='None'):
    # First run with all features (either bootstrapped or not)

    all_healthCodes = get_unique_healthCodes(dataset)
    count=1
    for indv in all_healthCodes:
        print(f'healthCode {indv} ({count} of total {len(all_healthCodes)}) ------------------')
        for m in model:
            ds = dataset[dataset['healthCode'] == indv]
            bp_predictor = BloodPresurePredictor(m, ntrees)
            bp_predictor.predict(ds)
            log_exp(log_path, bp_predictor, aug='None', N=N, double=False, bootstrap=(bootstrap_iter>0))     # log results
        
            top_n = list(bp_predictor.feature_importances.keys())[:N]       # get top N features from dict 
            cols = key + top_n + target                                     # add key and target columns
            bp_predictor.predict(dataset[cols])                             # predict with top N features
            log_exp(log_path, bp_predictor, aug='None', N=N, double=True, bootstrap=(bootstrap_iter>0))   # log results
        count += 1   
        print()

# %% [markdown]
# **Get Top N features as well as error measures with XGB model** - without Bootstraping

# %%
############################################# PARAMETERS #############################################
N = 5                               # Number of most important features to display
model = 'xgb'                        # rf or xgb (Random Forest or XGBoost)
ntrees = 60                         # Number of trees in the forest
double_run = False                  # Whether to use a second run with top N features or not
bootstrap = False                   # Whether to use bootstrap samples
bootstrap_iter = 100               # Number of bootstrap iterations
bootstrap_size = 0.8                # Portion of the dataset to sample for bootstrap
key = ['healthCode', 'date']        # Columns to use as key
target = ['systolic', 'diastolic']  # Columns to predict
log_path = 'exp_log.csv'            # Path of file to log experiment results


############################################# EXPERIMENTS #############################################
# Predicting systolic BP using baseline with non NaN values
print('BASELINE - NO AUGMENTATION')
dataset = baseline
aug = 'None'
experiment(dataset, model, ntrees, N, key, target, double_run=double_run, log_path=log_path, 
           bootstrap_iter=bootstrap_iter, bootstrap_size=bootstrap_size, aug=aug)
print('--------------------------------------------------------------------------------')

# Predicting systolic BP using k-roll augmentation with non NaN values
print('K-ROLL AUGMENTATION')
dataset = augmented_k
aug = 'K-roll'
experiment(dataset, model, ntrees, N, key, target, double_run=double_run, log_path=log_path, 
           bootstrap_iter=bootstrap_iter, bootstrap_size=bootstrap_size, aug=aug)
print('--------------------------------------------------------------------------------')


# Predicting systolic BP using knn intra augmentation with non NaN values
print('KNN INTRA AUGMENTATION')
dataset = augmented_intra
aug = 'KNN-intra'
experiment(dataset, model, ntrees, N, key, target, double_run=double_run, log_path=log_path, 
           bootstrap_iter=bootstrap_iter, bootstrap_size=bootstrap_size, aug=aug)
print('--------------------------------------------------------------------------------')


# Predicting systolic BP using knn inter augmentation with non NaN values
print('KNN INTER AUGMENTATION')
dataset = augmented_inter
aug = 'KNN-inter'
experiment(dataset, model, ntrees, N, key, target, double_run=double_run, log_path=log_path, 
           bootstrap_iter=bootstrap_iter, bootstrap_size=bootstrap_size, aug=aug)
print('--------------------------------------------------------------------------------')
# Out:
# BASELINE - NO AUGMENTATION
# dataset size: 21, model: xgb, ntrees: 60, sys_mae: 6.529, dias_mae: 4.507, top_n: floors; distance_cycling; sleep_minutes; distance_walking; active_calories, double run: False, bootstrap: True
# dataset size: 86, model: xgb, ntrees: 60, sys_mae: 8.333, dias_mae: 4.5, top_n: N/A, double run: True, bootstrap: True
# --------------------------------------------------------------------------------
# K-ROLL AUGMENTATION
# dataset size: 33, model: xgb, ntrees: 60, sys_mae: 6.051, dias_mae: 3.935, top_n: active_calories; steps; bed_time; floors; wo_calories, double run: False, bootstrap: True
# dataset size: 40, model: xgb, ntrees: 60, sys_mae: 9.625, dias_mae: 5.375, top_n: N/A, double run: True, bootstrap: True
# --------------------------------------------------------------------------------
# KNN INTRA AUGMENTATION
# dataset size: 127, model: xgb, ntrees: 60, sys_mae: 4.849, dias_mae: 3.956, top_n: steps; floors; wo_calories; active_calories; distance_cycling, double run: False, bootstrap: True
# dataset size: 365, model: xgb, ntrees: 60, sys_mae: 8.877, dias_mae: 6.575, top_n: N/A, double run: True, bootstrap: True
# --------------------------------------------------------------------------------
# KNN INTER AUGMENTATION
# dataset size: 881, model: xgb, ntrees: 60, sys_mae: 6.404, dias_mae: 5.142, top_n: wo_calories; awake_count; steps; sleep_minutes; bed_time, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 11.411, dias_mae: 9.634, top_n: N/A, double run: True, bootstrap: True
# --------------------------------------------------------------------------------

# %% [markdown]
# **Personalised BP Prediction**

# %%
############################################# PARAMETERS #############################################
N = 5                               # Number of most important features to display
model = ['rf', 'xgb']                        # rf or xgb (Random Forest or XGBoost)
ntrees = 60                         # Number of trees in the forest
double_run = False                  # Whether to use a second run with top N features or not
bootstrap = False                   # Whether to use bootstrap samples
bootstrap_iter = 100               # Number of bootstrap iterations
bootstrap_size = 0.8                # Portion of the dataset to sample for bootstrap
key = ['healthCode', 'date']        # Columns to use as key
target = ['systolic', 'diastolic']  # Columns to predict
log_path = 'exp_log.csv'            # Path of file to log experiment results


############################################# EXPERIMENTS #############################################
# Predicting BP using baseline with non NaN values
print('BASELINE - NO AUGMENTATION')
aug = 'None'

personalised_experiment(baseline, model, ntrees, N, key, target, double_run=False, log_path=log_path, aug=aug)
print('--------------------------------------------------------------------------------')

# Predicting BP using k-roll augmentation with non NaN values
print('K-ROLL AUGMENTATION')
dataset = augmented_k
aug = 'K-roll'
personalised_experiment(dataset, model, ntrees, N, key, target, double_run=double_run, log_path=log_path, 
           bootstrap_iter=bootstrap_iter, bootstrap_size=bootstrap_size, aug=aug)
print('--------------------------------------------------------------------------------')


# Predicting BP using knn intra augmentation with non NaN values
print('KNN INTRA AUGMENTATION')
dataset = augmented_intra
aug = 'KNN-intra'
personalised_experiment(dataset, model, ntrees, N, key, target, double_run=double_run, log_path=log_path, aug=aug)
print('--------------------------------------------------------------------------------')


# Predicting BP using knn inter augmentation with non NaN values
print('KNN INTER AUGMENTATION')
dataset = augmented_inter
aug = 'KNN-inter'
personalised_experiment(dataset, model, ntrees, N, key, target, double_run=double_run, log_path=log_path, 
           bootstrap_iter=bootstrap_iter, bootstrap_size=bootstrap_size, aug=aug)
print('--------------------------------------------------------------------------------')
# Out:
# BASELINE - NO AUGMENTATION
# healthCode a88f3758-0e43-43bd-bc6a-55a0780ec643 (1 of total 1) ------------------
# dataset size: 3, model: rf, ntrees: 60, sys_mae: 6.0, dias_mae: 4.0, top_n: floors; wo_calories; active_minutes; distance_walking; active_calories, double run: False, bootstrap: False
# dataset size: 96, model: rf, ntrees: 60, sys_mae: 9.35, dias_mae: 7.55, top_n: N/A, double run: True, bootstrap: False
# dataset size: 3, model: xgb, ntrees: 60, sys_mae: 21.0, dias_mae: 5.0, top_n: distance_cycling; floors; wo_calories; active_minutes; distance_walking, double run: False, bootstrap: False
# dataset size: 96, model: xgb, ntrees: 60, sys_mae: 10.45, dias_mae: 7.8, top_n: N/A, double run: True, bootstrap: False
#
# --------------------------------------------------------------------------------
# K-ROLL AUGMENTATION
# healthCode a88f3758-0e43-43bd-bc6a-55a0780ec643 (1 of total 1) ------------------
# dataset size: 4, model: rf, ntrees: 60, sys_mae: 19.0, dias_mae: 5.0, top_n: floors; steps; wo_calories; distance_walking; bed_time, double run: False, bootstrap: True
# dataset size: 40, model: rf, ntrees: 60, sys_mae: 10.625, dias_mae: 6.25, top_n: N/A, double run: True, bootstrap: True
# dataset size: 4, model: xgb, ntrees: 60, sys_mae: 21.0, dias_mae: 5.0, top_n: floors; wo_calories; active_minutes; distance_walking; active_calories, double run: False, bootstrap: True
# dataset size: 160, model: xgb, ntrees: 60, sys_mae: 12.594, dias_mae: 6.812, top_n: N/A, double run: True, bootstrap: True
#
# --------------------------------------------------------------------------------
# KNN INTRA AUGMENTATION
# healthCode 6f8a0854-c9cf-4b89-b55a-a27f71fe09d3 (1 of total 7) ------------------
# dataset size: 15, model: rf, ntrees: 60, sys_mae: 4.0, dias_mae: 2.0, top_n: floors; distance_walking; sleep_minutes; bed_time; active_calories, double run: False, bootstrap: False
# dataset size: 339, model: rf, ntrees: 60, sys_mae: 8.676, dias_mae: 6.662, top_n: N/A, double run: True, bootstrap: False
# dataset size: 15, model: xgb, ntrees: 60, sys_mae: 4.0, dias_mae: 0.667, top_n: distance_walking; floors; active_calories; sleep_minutes; bed_time, double run: False, bootstrap: False
# dataset size: 339, model: xgb, ntrees: 60, sys_mae: 11.294, dias_mae: 7.779, top_n: N/A, double run: True, bootstrap: False
#
# healthCode 56170d78-0e9b-4b9c-8f1a-3c41580e59db (2 of total 7) ------------------
# dataset size: 3, model: rf, ntrees: 60, sys_mae: 6.0, dias_mae: 7.0, top_n: sleep_minutes; awake_count; bed_time; distance_walking; wo_calories, double run: False, bootstrap: False
# dataset size: 155, model: rf, ntrees: 60, sys_mae: 9.355, dias_mae: 6.452, top_n: N/A, double run: True, bootstrap: False
# dataset size: 3, model: xgb, ntrees: 60, sys_mae: 3.0, dias_mae: 1.0, top_n: distance_walking; floors; wo_calories; active_minutes; active_calories, double run: False, bootstrap: False
# dataset size: 365, model: xgb, ntrees: 60, sys_mae: 11.219, dias_mae: 8.863, top_n: N/A, double run: True, bootstrap: False
#
# healthCode 521822e1-514a-4d9d-b918-bd3ff6230865 (3 of total 7) ------------------
# dataset size: 4, model: rf, ntrees: 60, sys_mae: 0.0, dias_mae: 0.0, top_n: floors; wo_calories; active_minutes; distance_walking; active_calories, double run: False, bootstrap: False
# dataset size: 365, model: rf, ntrees: 60, sys_mae: 11.548, dias_mae: 6.37, top_n: N/A, double run: True, bootstrap: False
# dataset size: 4, model: xgb, ntrees: 60, sys_mae: 0.0, dias_mae: 0.0, top_n: floors; wo_calories; active_minutes; distance_walking; active_calories, double run: False, bootstrap: False
# dataset size: 365, model: xgb, ntrees: 60, sys_mae: 10.507, dias_mae: 7.0, top_n: N/A, double run: True, bootstrap: False
#
# healthCode eabc5b1b-1b42-4abb-808f-22f79046e886 (4 of total 7) ------------------
# dataset size: 3, model: rf, ntrees: 60, sys_mae: 10.0, dias_mae: 12.0, top_n: floors; wo_calories; active_minutes; distance_walking; active_calories, double run: False, bootstrap: False
# dataset size: 365, model: rf, ntrees: 60, sys_mae: 9.904, dias_mae: 6.74, top_n: N/A, double run: True, bootstrap: False
# dataset size: 3, model: xgb, ntrees: 60, sys_mae: 10.0, dias_mae: 12.0, top_n: floors; wo_calories; active_minutes; distance_walking; active_calories, double run: False, bootstrap: False
# dataset size: 365, model: xgb, ntrees: 60, sys_mae: 8.877, dias_mae: 8.0, top_n: N/A, double run: True, bootstrap: False
#
# healthCode 9e87a34d-5dfc-4152-b1fb-931b785d0d6f (5 of total 7) ------------------
# dataset size: 3, model: rf, ntrees: 60, sys_mae: 7.0, dias_mae: 0.0, top_n: steps; distance_walking; bed_time; sleep_minutes; awake_count, double run: False, bootstrap: False
# dataset size: 339, model: rf, ntrees: 60, sys_mae: 9.147, dias_mae: 5.618, top_n: N/A, double run: True, bootstrap: False
# dataset size: 3, model: xgb, ntrees: 60, sys_mae: 14.0, dias_mae: 0.0, top_n: distance_walking; floors; wo_calories; active_minutes; active_calories, double run: False, bootstrap: False
# dataset size: 365, model: xgb, ntrees: 60, sys_mae: 9.575, dias_mae: 6.767, top_n: N/A, double run: True, bootstrap: False
#
# healthCode 49694001-6bc7-44dc-a03c-eecf99364a13 (6 of total 7) ------------------
# dataset size: 16, model: rf, ntrees: 60, sys_mae: 2.75, dias_mae: 2.5, top_n: wo_calories; sleep_minutes; bed_time; distance_walking; steps, double run: False, bootstrap: False
# dataset size: 155, model: rf, ntrees: 60, sys_mae: 6.935, dias_mae: 5.065, top_n: N/A, double run: True, bootstrap: False
# dataset size: 16, model: xgb, ntrees: 60, sys_mae: 3.0, dias_mae: 4.0, top_n: floors; distance_walking; sleep_minutes; wo_calories; steps, double run: False, bootstrap: False
# dataset size: 155, model: xgb, ntrees: 60, sys_mae: 7.613, dias_mae: 6.258, top_n: N/A, double run: True, bootstrap: False
#
# healthCode a88f3758-0e43-43bd-bc6a-55a0780ec643 (7 of total 7) ------------------
# dataset size: 4, model: rf, ntrees: 60, sys_mae: 4.0, dias_mae: 2.0, top_n: wo_calories; bed_time; sleep_minutes; floors; steps, double run: False, bootstrap: False
# dataset size: 155, model: rf, ntrees: 60, sys_mae: 8.032, dias_mae: 6.032, top_n: N/A, double run: True, bootstrap: False
# dataset size: 4, model: xgb, ntrees: 60, sys_mae: 21.0, dias_mae: 5.0, top_n: floors; wo_calories; active_minutes; distance_walking; active_calories, double run: False, bootstrap: False
# dataset size: 365, model: xgb, ntrees: 60, sys_mae: 10.849, dias_mae: 7.521, top_n: N/A, double run: True, bootstrap: False
#
# --------------------------------------------------------------------------------
# KNN INTER AUGMENTATION
# healthCode 32eda3ee-8ff0-42f1-9e2e-96dd51ed5ff0 (1 of total 58) ------------------
# dataset size: 18, model: rf, ntrees: 60, sys_mae: 2.0, dias_mae: 1.25, top_n: sleep_minutes; awake_count; distance_walking; steps; bed_time, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 10.308, dias_mae: 8.433, top_n: N/A, double run: True, bootstrap: True
# dataset size: 18, model: xgb, ntrees: 60, sys_mae: 2.75, dias_mae: 2.25, top_n: distance_walking; sleep_minutes; bed_time; awake_count; floors, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 11.857, dias_mae: 9.277, top_n: N/A, double run: True, bootstrap: True
#
# healthCode a7d67779-d082-4c74-9a06-f0544a37d378 (2 of total 58) ------------------
# dataset size: 9, model: rf, ntrees: 60, sys_mae: 2.5, dias_mae: 1.5, top_n: sleep_minutes; wo_calories; active_calories; bed_time; awake_count, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 9.942, dias_mae: 7.83, top_n: N/A, double run: True, bootstrap: True
# dataset size: 9, model: xgb, ntrees: 60, sys_mae: 9.0, dias_mae: 4.0, top_n: awake_count; distance_walking; active_calories; bed_time; sleep_minutes, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 11.598, dias_mae: 9.223, top_n: N/A, double run: True, bootstrap: True
#
# healthCode 78ff7486-e134-4c74-ba03-2b1fe3c76933 (3 of total 58) ------------------
# dataset size: 3, model: rf, ntrees: 60, sys_mae: 11.0, dias_mae: 2.0, top_n: active_calories; wo_calories; bed_time; sleep_minutes; awake_count, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 9.625, dias_mae: 8.304, top_n: N/A, double run: True, bootstrap: True
# dataset size: 3, model: xgb, ntrees: 60, sys_mae: 4.0, dias_mae: 0.0, top_n: active_calories; floors; wo_calories; active_minutes; distance_walking, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 10.871, dias_mae: 8.536, top_n: N/A, double run: True, bootstrap: True
#
# healthCode 84a68df3-c77a-4959-adf8-909935df2f4e (4 of total 58) ------------------
# dataset size: 6, model: rf, ntrees: 60, sys_mae: 1.0, dias_mae: 2.0, top_n: bed_time; wo_calories; awake_count; sleep_minutes; active_calories, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 10.179, dias_mae: 8.045, top_n: N/A, double run: True, bootstrap: True
# dataset size: 6, model: xgb, ntrees: 60, sys_mae: 1.0, dias_mae: 2.0, top_n: sleep_minutes; wo_calories; floors; active_minutes; distance_walking, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 11.254, dias_mae: 9.71, top_n: N/A, double run: True, bootstrap: True
#
# healthCode c85e5a35-20ce-492d-8886-6132c881416b (5 of total 58) ------------------
# dataset size: 21, model: rf, ntrees: 60, sys_mae: 17.8, dias_mae: 17.4, top_n: awake_count; wo_calories; steps; sleep_minutes; floors, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 11.036, dias_mae: 8.589, top_n: N/A, double run: True, bootstrap: True
# dataset size: 21, model: xgb, ntrees: 60, sys_mae: 13.4, dias_mae: 25.8, top_n: awake_count; sleep_minutes; bed_time; floors; wo_calories, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 11.018, dias_mae: 9.018, top_n: N/A, double run: True, bootstrap: True
#
# healthCode 9524e5fd-8e28-47b2-b11c-e1851fb45083 (6 of total 58) ------------------
# dataset size: 9, model: rf, ntrees: 60, sys_mae: 1.0, dias_mae: 0.0, top_n: sleep_minutes; awake_count; bed_time; active_calories; wo_calories, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 11.402, dias_mae: 9.152, top_n: N/A, double run: True, bootstrap: True
# dataset size: 9, model: xgb, ntrees: 60, sys_mae: 2.0, dias_mae: 0.0, top_n: floors; wo_calories; active_minutes; distance_walking; active_calories, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 11.92, dias_mae: 9.21, top_n: N/A, double run: True, bootstrap: True
#
# healthCode 7c82c6cc-18fd-4408-b7dd-460d1b5f95df (7 of total 58) ------------------
# dataset size: 7, model: rf, ntrees: 60, sys_mae: 12.5, dias_mae: 4.5, top_n: awake_count; wo_calories; sleep_minutes; distance_walking; steps, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 10.92, dias_mae: 8.018, top_n: N/A, double run: True, bootstrap: True
# dataset size: 7, model: xgb, ntrees: 60, sys_mae: 7.5, dias_mae: 7.5, top_n: sleep_minutes; bed_time; wo_calories; steps; distance_walking, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 11.406, dias_mae: 8.272, top_n: N/A, double run: True, bootstrap: True
#
# healthCode 1943f4dd-e304-4355-8e38-9d638e7987c3 (8 of total 58) ------------------
# dataset size: 23, model: rf, ntrees: 60, sys_mae: 6.6, dias_mae: 1.2, top_n: wo_calories; steps; bed_time; floors; distance_walking, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 10.241, dias_mae: 9.174, top_n: N/A, double run: True, bootstrap: True
# dataset size: 23, model: xgb, ntrees: 60, sys_mae: 0.8, dias_mae: 0.6, top_n: wo_calories; floors; distance_walking; steps; awake_count, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 10.772, dias_mae: 8.772, top_n: N/A, double run: True, bootstrap: True
#
# healthCode 1e399fc2-7854-4608-b8cc-ddac6c77e005 (9 of total 58) ------------------
# dataset size: 11, model: rf, ntrees: 60, sys_mae: 0.333, dias_mae: 5.0, top_n: wo_calories; bed_time; active_calories; steps; awake_count, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 11.237, dias_mae: 8.214, top_n: N/A, double run: True, bootstrap: True
# dataset size: 11, model: xgb, ntrees: 60, sys_mae: 4.333, dias_mae: 8.667, top_n: sleep_minutes; distance_walking; awake_count; floors; wo_calories, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 11.978, dias_mae: 9.165, top_n: N/A, double run: True, bootstrap: True
#
# healthCode 12a38046-1512-409a-b3a1-6046e97e650e (10 of total 58) ------------------
# dataset size: 17, model: rf, ntrees: 60, sys_mae: 8.0, dias_mae: 1.75, top_n: floors; bed_time; distance_walking; wo_calories; steps, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 10.022, dias_mae: 8.915, top_n: N/A, double run: True, bootstrap: True
# dataset size: 17, model: xgb, ntrees: 60, sys_mae: 12.5, dias_mae: 7.75, top_n: awake_count; bed_time; steps; distance_walking; sleep_minutes, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 11.223, dias_mae: 9.009, top_n: N/A, double run: True, bootstrap: True
#
# healthCode 601b719e-5310-44be-972a-170265931579 (11 of total 58) ------------------
# dataset size: 15, model: rf, ntrees: 60, sys_mae: 5.667, dias_mae: 4.0, top_n: floors; active_calories; sleep_minutes; awake_count; wo_calories, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 10.812, dias_mae: 8.062, top_n: N/A, double run: True, bootstrap: True
# dataset size: 15, model: xgb, ntrees: 60, sys_mae: 7.0, dias_mae: 4.0, top_n: floors; sleep_minutes; active_calories; wo_calories; bed_time, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 11.188, dias_mae: 8.875, top_n: N/A, double run: True, bootstrap: True
#
# healthCode 809ba5a3-a0ed-4d44-a496-ff3040b19973 (12 of total 58) ------------------
# dataset size: 13, model: rf, ntrees: 60, sys_mae: 0.333, dias_mae: 4.333, top_n: bed_time; distance_walking; wo_calories; awake_count; steps, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 9.607, dias_mae: 7.438, top_n: N/A, double run: True, bootstrap: True
# dataset size: 13, model: xgb, ntrees: 60, sys_mae: 0.0, dias_mae: 8.0, top_n: distance_walking; steps; floors; wo_calories; active_minutes, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 11.188, dias_mae: 9.844, top_n: N/A, double run: True, bootstrap: True
#
# healthCode 9fcb1379-a2f3-4a56-87f1-ff709cf39edb (13 of total 58) ------------------
# dataset size: 18, model: rf, ntrees: 60, sys_mae: 6.75, dias_mae: 1.75, top_n: sleep_minutes; wo_calories; floors; bed_time; awake_count, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 9.763, dias_mae: 8.188, top_n: N/A, double run: True, bootstrap: True
# dataset size: 18, model: xgb, ntrees: 60, sys_mae: 3.5, dias_mae: 4.5, top_n: wo_calories; bed_time; floors; sleep_minutes; awake_count, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 11.978, dias_mae: 8.772, top_n: N/A, double run: True, bootstrap: True
#
# healthCode eb92585e-e5ae-4d81-ab9b-5bdec37c4253 (14 of total 58) ------------------
# dataset size: 13, model: rf, ntrees: 60, sys_mae: 3.0, dias_mae: 3.333, top_n: steps; sleep_minutes; wo_calories; awake_count; bed_time, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 11.594, dias_mae: 8.286, top_n: N/A, double run: True, bootstrap: True
# dataset size: 13, model: xgb, ntrees: 60, sys_mae: 1.0, dias_mae: 1.333, top_n: steps; sleep_minutes; distance_walking; wo_calories; bed_time, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 11.103, dias_mae: 9.054, top_n: N/A, double run: True, bootstrap: True
#
# healthCode fefce9a1-f76b-4e1e-b436-c268e6e10f20 (15 of total 58) ------------------
# dataset size: 3, model: rf, ntrees: 60, sys_mae: 0.0, dias_mae: 1.0, top_n: wo_calories; steps; awake_count; bed_time; sleep_minutes, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 11.321, dias_mae: 8.598, top_n: N/A, double run: True, bootstrap: True
# dataset size: 3, model: xgb, ntrees: 60, sys_mae: 0.0, dias_mae: 3.0, top_n: floors; wo_calories; active_minutes; distance_walking; active_calories, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 11.161, dias_mae: 9.554, top_n: N/A, double run: True, bootstrap: True
#
# healthCode 6f8a0854-c9cf-4b89-b55a-a27f71fe09d3 (16 of total 58) ------------------
# dataset size: 15, model: rf, ntrees: 60, sys_mae: 7.333, dias_mae: 4.0, top_n: awake_count; bed_time; wo_calories; floors; sleep_minutes, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 11.04, dias_mae: 8.232, top_n: N/A, double run: True, bootstrap: True
# dataset size: 15, model: xgb, ntrees: 60, sys_mae: 2.333, dias_mae: 3.333, top_n: sleep_minutes; floors; active_calories; awake_count; distance_walking, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 11.594, dias_mae: 8.621, top_n: N/A, double run: True, bootstrap: True
#
# healthCode fdab9004-fa33-4e23-a99a-fb11ca5deb04 (17 of total 58) ------------------
# dataset size: 5, model: rf, ntrees: 60, sys_mae: 2.0, dias_mae: 2.0, top_n: active_calories; sleep_minutes; wo_calories; bed_time; distance_walking, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 10.138, dias_mae: 8.562, top_n: N/A, double run: True, bootstrap: True
# dataset size: 5, model: xgb, ntrees: 60, sys_mae: 9.0, dias_mae: 4.0, top_n: active_calories; sleep_minutes; floors; wo_calories; active_minutes, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 11.929, dias_mae: 10.022, top_n: N/A, double run: True, bootstrap: True
#
# healthCode 56170d78-0e9b-4b9c-8f1a-3c41580e59db (18 of total 58) ------------------
# dataset size: 3, model: rf, ntrees: 60, sys_mae: 6.0, dias_mae: 10.0, top_n: floors; distance_walking; sleep_minutes; bed_time; wo_calories, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 10.326, dias_mae: 8.888, top_n: N/A, double run: True, bootstrap: True
# dataset size: 3, model: xgb, ntrees: 60, sys_mae: 3.0, dias_mae: 1.0, top_n: distance_walking; floors; wo_calories; active_minutes; active_calories, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 11.295, dias_mae: 8.804, top_n: N/A, double run: True, bootstrap: True
#
# healthCode 521822e1-514a-4d9d-b918-bd3ff6230865 (19 of total 58) ------------------
# dataset size: 4, model: rf, ntrees: 60, sys_mae: 0.0, dias_mae: 0.0, top_n: floors; wo_calories; active_minutes; distance_walking; active_calories, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 9.219, dias_mae: 7.656, top_n: N/A, double run: True, bootstrap: True
# dataset size: 4, model: xgb, ntrees: 60, sys_mae: 0.0, dias_mae: 0.0, top_n: floors; wo_calories; active_minutes; distance_walking; active_calories, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 9.54, dias_mae: 8.978, top_n: N/A, double run: True, bootstrap: True
#
# healthCode f137ff8d-ac8a-488e-9aa9-4d30b9d924da (20 of total 58) ------------------
# dataset size: 3, model: rf, ntrees: 60, sys_mae: 28.0, dias_mae: 8.0, top_n: active_calories; bed_time; sleep_minutes; wo_calories; awake_count, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 9.5, dias_mae: 8.232, top_n: N/A, double run: True, bootstrap: True
# dataset size: 3, model: xgb, ntrees: 60, sys_mae: 28.0, dias_mae: 12.0, top_n: active_calories; floors; wo_calories; active_minutes; distance_walking, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 11.152, dias_mae: 8.835, top_n: N/A, double run: True, bootstrap: True
#
# healthCode 254e7ff7-6ba1-4ab4-9315-83fdf153a4c0 (21 of total 58) ------------------
# dataset size: 4, model: rf, ntrees: 60, sys_mae: 3.0, dias_mae: 3.0, top_n: bed_time; sleep_minutes; floors; distance_walking; wo_calories, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 11.353, dias_mae: 8.598, top_n: N/A, double run: True, bootstrap: True
# dataset size: 4, model: xgb, ntrees: 60, sys_mae: 0.0, dias_mae: 2.0, top_n: floors; distance_walking; wo_calories; active_minutes; active_calories, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 11.134, dias_mae: 8.844, top_n: N/A, double run: True, bootstrap: True
#
# healthCode eabc5b1b-1b42-4abb-808f-22f79046e886 (22 of total 58) ------------------
# dataset size: 3, model: rf, ntrees: 60, sys_mae: 6.0, dias_mae: 6.0, top_n: steps; awake_count; wo_calories; sleep_minutes; floors, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 10.571, dias_mae: 8.098, top_n: N/A, double run: True, bootstrap: True
# dataset size: 3, model: xgb, ntrees: 60, sys_mae: 0.0, dias_mae: 0.0, top_n: distance_walking; floors; wo_calories; active_minutes; active_calories, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 12.004, dias_mae: 8.772, top_n: N/A, double run: True, bootstrap: True
#
# healthCode 75abbf64-702a-4c83-b07a-50ab9149f747 (23 of total 58) ------------------
# dataset size: 6, model: rf, ntrees: 60, sys_mae: 0.0, dias_mae: 1.0, top_n: awake_count; steps; bed_time; sleep_minutes; floors, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 9.982, dias_mae: 8.188, top_n: N/A, double run: True, bootstrap: True
# dataset size: 6, model: xgb, ntrees: 60, sys_mae: 0.0, dias_mae: 0.0, top_n: steps; floors; wo_calories; active_minutes; distance_walking, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 10.799, dias_mae: 7.808, top_n: N/A, double run: True, bootstrap: True
#
# healthCode d619fd19-0555-45da-9efd-7edcaf841c77 (24 of total 58) ------------------
# dataset size: 4, model: rf, ntrees: 60, sys_mae: 0.0, dias_mae: 3.0, top_n: active_calories; wo_calories; sleep_minutes; bed_time; awake_count, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 10.116, dias_mae: 7.906, top_n: N/A, double run: True, bootstrap: True
# dataset size: 4, model: xgb, ntrees: 60, sys_mae: 2.0, dias_mae: 5.0, top_n: active_calories; floors; wo_calories; active_minutes; distance_walking, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 10.545, dias_mae: 8.308, top_n: N/A, double run: True, bootstrap: True
#
# healthCode 75038b73-3de1-41fc-8579-0c5cf9fa3b3f (25 of total 58) ------------------
# dataset size: 12, model: rf, ntrees: 60, sys_mae: 4.333, dias_mae: 2.0, top_n: floors; wo_calories; bed_time; sleep_minutes; awake_count, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 10.469, dias_mae: 9.129, top_n: N/A, double run: True, bootstrap: True
# dataset size: 12, model: xgb, ntrees: 60, sys_mae: 4.333, dias_mae: 0.667, top_n: floors; sleep_minutes; distance_walking; wo_calories; bed_time, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 11.058, dias_mae: 9.781, top_n: N/A, double run: True, bootstrap: True
#
# healthCode 9e87a34d-5dfc-4152-b1fb-931b785d0d6f (26 of total 58) ------------------
# dataset size: 3, model: rf, ntrees: 60, sys_mae: 6.0, dias_mae: 0.0, top_n: steps; wo_calories; distance_walking; bed_time; sleep_minutes, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 10.04, dias_mae: 8.321, top_n: N/A, double run: True, bootstrap: True
# dataset size: 3, model: xgb, ntrees: 60, sys_mae: 14.0, dias_mae: 0.0, top_n: distance_walking; floors; wo_calories; active_minutes; active_calories, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 10.598, dias_mae: 8.42, top_n: N/A, double run: True, bootstrap: True
#
# healthCode 9448fd08-37b6-4ddf-a7cf-29dbf62db53e (27 of total 58) ------------------
# dataset size: 4, model: rf, ntrees: 60, sys_mae: 5.0, dias_mae: 4.0, top_n: distance_walking; wo_calories; steps; bed_time; sleep_minutes, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 10.058, dias_mae: 8.259, top_n: N/A, double run: True, bootstrap: True
# dataset size: 4, model: xgb, ntrees: 60, sys_mae: 5.0, dias_mae: 4.0, top_n: distance_walking; floors; wo_calories; active_minutes; active_calories, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 10.754, dias_mae: 8.991, top_n: N/A, double run: True, bootstrap: True
#
# healthCode e20bf535-8114-455c-b860-751dd304205e (28 of total 58) ------------------
# dataset size: 13, model: rf, ntrees: 60, sys_mae: 0.0, dias_mae: 0.0, top_n: floors; wo_calories; active_minutes; distance_walking; active_calories, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 10.772, dias_mae: 8.92, top_n: N/A, double run: True, bootstrap: True
# dataset size: 13, model: xgb, ntrees: 60, sys_mae: 0.0, dias_mae: 0.0, top_n: floors; wo_calories; active_minutes; distance_walking; active_calories, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 11.067, dias_mae: 9.893, top_n: N/A, double run: True, bootstrap: True
#
# healthCode 49694001-6bc7-44dc-a03c-eecf99364a13 (29 of total 58) ------------------
# dataset size: 16, model: rf, ntrees: 60, sys_mae: 3.5, dias_mae: 2.25, top_n: sleep_minutes; bed_time; awake_count; distance_walking; steps, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 9.888, dias_mae: 8.263, top_n: N/A, double run: True, bootstrap: True
# dataset size: 16, model: xgb, ntrees: 60, sys_mae: 4.25, dias_mae: 2.0, top_n: bed_time; awake_count; sleep_minutes; steps; distance_walking, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 11.0, dias_mae: 8.625, top_n: N/A, double run: True, bootstrap: True
#
# healthCode 0320d51d-efa3-45bb-a892-bce450822c30 (30 of total 58) ------------------
# dataset size: 3, model: rf, ntrees: 60, sys_mae: 6.0, dias_mae: 7.0, top_n: distance_walking; wo_calories; bed_time; floors; sleep_minutes, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 10.554, dias_mae: 8.469, top_n: N/A, double run: True, bootstrap: True
# dataset size: 3, model: xgb, ntrees: 60, sys_mae: 11.0, dias_mae: 9.0, top_n: floors; wo_calories; active_minutes; distance_walking; active_calories, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 11.281, dias_mae: 8.612, top_n: N/A, double run: True, bootstrap: True
#
# healthCode d3246c98-307c-4e20-97b4-fabde927964d (31 of total 58) ------------------
# dataset size: 3, model: rf, ntrees: 60, sys_mae: 5.0, dias_mae: 7.0, top_n: bed_time; wo_calories; floors; distance_walking; distance_cycling, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 10.5, dias_mae: 8.098, top_n: N/A, double run: True, bootstrap: True
# dataset size: 3, model: xgb, ntrees: 60, sys_mae: 4.0, dias_mae: 3.0, top_n: distance_cycling; floors; wo_calories; active_minutes; distance_walking, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 11.812, dias_mae: 9.393, top_n: N/A, double run: True, bootstrap: True
#
# healthCode 7034dcee-c0e4-4d52-8adb-221735a24c28 (32 of total 58) ------------------
# dataset size: 6, model: rf, ntrees: 60, sys_mae: 5.5, dias_mae: 2.5, top_n: steps; bed_time; wo_calories; sleep_minutes; distance_walking, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 9.862, dias_mae: 8.116, top_n: N/A, double run: True, bootstrap: True
# dataset size: 6, model: xgb, ntrees: 60, sys_mae: 6.0, dias_mae: 0.0, top_n: distance_walking; bed_time; floors; steps; wo_calories, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 11.621, dias_mae: 8.576, top_n: N/A, double run: True, bootstrap: True
#
# healthCode 83f88a25-ceae-4834-a787-81e4b72d6c2f (33 of total 58) ------------------
# dataset size: 4, model: rf, ntrees: 60, sys_mae: 0.0, dias_mae: 5.0, top_n: awake_count; floors; sleep_minutes; bed_time; wo_calories, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 10.411, dias_mae: 8.991, top_n: N/A, double run: True, bootstrap: True
# dataset size: 4, model: xgb, ntrees: 60, sys_mae: 0.0, dias_mae: 5.0, top_n: floors; wo_calories; active_minutes; distance_walking; active_calories, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 11.0, dias_mae: 8.897, top_n: N/A, double run: True, bootstrap: True
#
# healthCode 678c84f1-57ec-4851-8637-a2b7d4f33782 (34 of total 58) ------------------
# dataset size: 4, model: rf, ntrees: 60, sys_mae: 4.0, dias_mae: 1.0, top_n: awake_count; sleep_minutes; bed_time; floors; wo_calories, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 10.232, dias_mae: 9.384, top_n: N/A, double run: True, bootstrap: True
# dataset size: 4, model: xgb, ntrees: 60, sys_mae: 20.0, dias_mae: 10.0, top_n: floors; wo_calories; active_minutes; distance_walking; active_calories, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 12.621, dias_mae: 8.281, top_n: N/A, double run: True, bootstrap: True
#
# healthCode f568f138-1d0f-48f6-9a97-c62e1bdd60cc (35 of total 58) ------------------
# dataset size: 10, model: rf, ntrees: 60, sys_mae: 0.5, dias_mae: 3.5, top_n: sleep_minutes; bed_time; wo_calories; distance_walking; floors, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 10.862, dias_mae: 8.799, top_n: N/A, double run: True, bootstrap: True
# dataset size: 10, model: xgb, ntrees: 60, sys_mae: 18.0, dias_mae: 7.0, top_n: sleep_minutes; distance_walking; floors; wo_calories; active_minutes, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 11.085, dias_mae: 9.661, top_n: N/A, double run: True, bootstrap: True
#
# healthCode 50af1e32-330d-4e7a-bc29-aea6081cc7d9 (36 of total 58) ------------------
# dataset size: 3, model: rf, ntrees: 60, sys_mae: 6.0, dias_mae: 5.0, top_n: bed_time; wo_calories; steps; sleep_minutes; floors, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 10.821, dias_mae: 8.433, top_n: N/A, double run: True, bootstrap: True
# dataset size: 3, model: xgb, ntrees: 60, sys_mae: 11.0, dias_mae: 12.0, top_n: steps; floors; wo_calories; active_minutes; distance_walking, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 12.04, dias_mae: 9.536, top_n: N/A, double run: True, bootstrap: True
#
# healthCode c6c66f3c-c65a-4169-8bfb-93ab26be1614 (37 of total 58) ------------------
# dataset size: 5, model: rf, ntrees: 60, sys_mae: 0.0, dias_mae: 1.0, top_n: sleep_minutes; distance_walking; wo_calories; bed_time; active_calories, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 11.661, dias_mae: 9.308, top_n: N/A, double run: True, bootstrap: True
# dataset size: 5, model: xgb, ntrees: 60, sys_mae: 9.0, dias_mae: 0.0, top_n: distance_walking; active_calories; floors; wo_calories; active_minutes, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 10.862, dias_mae: 9.638, top_n: N/A, double run: True, bootstrap: True
#
# healthCode 528b909c-a1d1-44b5-9fa7-e8ea36f7a54d (38 of total 58) ------------------
# dataset size: 5, model: rf, ntrees: 60, sys_mae: 3.0, dias_mae: 5.0, top_n: bed_time; sleep_minutes; wo_calories; steps; floors, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 10.272, dias_mae: 8.656, top_n: N/A, double run: True, bootstrap: True
# dataset size: 5, model: xgb, ntrees: 60, sys_mae: 2.0, dias_mae: 1.0, top_n: sleep_minutes; floors; steps; wo_calories; active_minutes, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 10.393, dias_mae: 9.107, top_n: N/A, double run: True, bootstrap: True
#
# healthCode 2340a919-1aee-4b7d-8357-839a61752ef9 (39 of total 58) ------------------
# dataset size: 11, model: rf, ntrees: 60, sys_mae: 1.0, dias_mae: 3.333, top_n: bed_time; sleep_minutes; awake_count; distance_walking; wo_calories, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 10.192, dias_mae: 8.531, top_n: N/A, double run: True, bootstrap: True
# dataset size: 11, model: xgb, ntrees: 60, sys_mae: 3.0, dias_mae: 3.333, top_n: sleep_minutes; distance_walking; floors; wo_calories; active_minutes, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 12.665, dias_mae: 10.04, top_n: N/A, double run: True, bootstrap: True
#
# healthCode 552417f4-a4aa-4004-b1a7-0e97ac3b316a (40 of total 58) ------------------
# dataset size: 8, model: rf, ntrees: 60, sys_mae: 6.5, dias_mae: 4.0, top_n: sleep_minutes; bed_time; awake_count; wo_calories; steps, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 10.232, dias_mae: 8.737, top_n: N/A, double run: True, bootstrap: True
# dataset size: 8, model: xgb, ntrees: 60, sys_mae: 7.0, dias_mae: 3.5, top_n: awake_count; bed_time; sleep_minutes; steps; distance_walking, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 10.951, dias_mae: 8.518, top_n: N/A, double run: True, bootstrap: True
#
# healthCode 0197dffc-ed27-4961-aa18-98e691685c37 (41 of total 58) ------------------
# dataset size: 3, model: rf, ntrees: 60, sys_mae: 3.0, dias_mae: 5.0, top_n: steps; wo_calories; bed_time; distance_walking; sleep_minutes, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 10.107, dias_mae: 7.478, top_n: N/A, double run: True, bootstrap: True
# dataset size: 3, model: xgb, ntrees: 60, sys_mae: 14.0, dias_mae: 18.0, top_n: floors; wo_calories; active_minutes; distance_walking; active_calories, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 11.433, dias_mae: 8.746, top_n: N/A, double run: True, bootstrap: True
#
# healthCode 9de6d135-8d52-4363-b836-c90a1841843d (42 of total 58) ------------------
# dataset size: 4, model: rf, ntrees: 60, sys_mae: 3.0, dias_mae: 0.0, top_n: sleep_minutes; floors; bed_time; awake_count; wo_calories, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 10.192, dias_mae: 8.429, top_n: N/A, double run: True, bootstrap: True
# dataset size: 4, model: xgb, ntrees: 60, sys_mae: 0.0, dias_mae: 0.0, top_n: floors; wo_calories; active_minutes; distance_walking; active_calories, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 10.933, dias_mae: 8.433, top_n: N/A, double run: True, bootstrap: True
#
# healthCode 25817f05-ef94-4daf-a87b-a47e9be1f540 (43 of total 58) ------------------
# dataset size: 3, model: rf, ntrees: 60, sys_mae: 7.0, dias_mae: 4.0, top_n: distance_walking; steps; floors; sleep_minutes; awake_count, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 11.036, dias_mae: 8.094, top_n: N/A, double run: True, bootstrap: True
# dataset size: 3, model: xgb, ntrees: 60, sys_mae: 10.0, dias_mae: 5.0, top_n: distance_walking; floors; wo_calories; active_minutes; active_calories, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 12.746, dias_mae: 9.464, top_n: N/A, double run: True, bootstrap: True
#
# healthCode 05d113f0-a786-481d-b45c-52159ba95145 (44 of total 58) ------------------
# dataset size: 3, model: rf, ntrees: 60, sys_mae: 2.0, dias_mae: 0.0, top_n: floors; sleep_minutes; awake_count; wo_calories; distance_walking, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 10.469, dias_mae: 8.634, top_n: N/A, double run: True, bootstrap: True
# dataset size: 3, model: xgb, ntrees: 60, sys_mae: 0.0, dias_mae: 0.0, top_n: distance_walking; floors; wo_calories; active_minutes; active_calories, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 11.411, dias_mae: 8.161, top_n: N/A, double run: True, bootstrap: True
#
# healthCode 37633071-388d-4e6e-b6fc-29e37a70a936 (45 of total 58) ------------------
# dataset size: 3, model: rf, ntrees: 60, sys_mae: 6.0, dias_mae: 6.0, top_n: awake_count; wo_calories; bed_time; distance_walking; sleep_minutes, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 10.737, dias_mae: 8.08, top_n: N/A, double run: True, bootstrap: True
# dataset size: 3, model: xgb, ntrees: 60, sys_mae: 7.0, dias_mae: 5.0, top_n: distance_walking; floors; wo_calories; active_minutes; active_calories, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 11.54, dias_mae: 8.46, top_n: N/A, double run: True, bootstrap: True
#
# healthCode 4dd5d91c-e079-4d5f-bc72-034699e2c51b (46 of total 58) ------------------
# dataset size: 3, model: rf, ntrees: 60, sys_mae: 10.0, dias_mae: 5.0, top_n: awake_count; bed_time; floors; distance_walking; wo_calories, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 10.054, dias_mae: 8.076, top_n: N/A, double run: True, bootstrap: True
# dataset size: 3, model: xgb, ntrees: 60, sys_mae: 10.0, dias_mae: 4.0, top_n: distance_walking; floors; wo_calories; active_minutes; active_calories, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 11.839, dias_mae: 9.415, top_n: N/A, double run: True, bootstrap: True
#
# healthCode a88f3758-0e43-43bd-bc6a-55a0780ec643 (47 of total 58) ------------------
# dataset size: 4, model: rf, ntrees: 60, sys_mae: 19.0, dias_mae: 5.0, top_n: steps; wo_calories; floors; bed_time; awake_count, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 10.996, dias_mae: 7.616, top_n: N/A, double run: True, bootstrap: True
# dataset size: 4, model: xgb, ntrees: 60, sys_mae: 4.0, dias_mae: 3.0, top_n: distance_cycling; floors; wo_calories; active_minutes; distance_walking, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 12.049, dias_mae: 9.054, top_n: N/A, double run: True, bootstrap: True
#
# healthCode 3d9522ed-bc28-485a-a4ad-27b4d94343b4 (48 of total 58) ------------------
# dataset size: 4, model: rf, ntrees: 60, sys_mae: 0.0, dias_mae: 0.0, top_n: floors; wo_calories; active_minutes; distance_walking; active_calories, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 11.089, dias_mae: 8.558, top_n: N/A, double run: True, bootstrap: True
# dataset size: 4, model: xgb, ntrees: 60, sys_mae: 0.0, dias_mae: 0.0, top_n: floors; wo_calories; active_minutes; distance_walking; active_calories, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 12.509, dias_mae: 10.424, top_n: N/A, double run: True, bootstrap: True
#
# healthCode 9a84631c-7153-4154-820b-48744cb5b298 (49 of total 58) ------------------
# dataset size: 6, model: rf, ntrees: 60, sys_mae: 0.0, dias_mae: 0.0, top_n: floors; wo_calories; active_minutes; distance_walking; active_calories, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 10.938, dias_mae: 9.161, top_n: N/A, double run: True, bootstrap: True
# dataset size: 6, model: xgb, ntrees: 60, sys_mae: 0.0, dias_mae: 0.0, top_n: floors; wo_calories; active_minutes; distance_walking; active_calories, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 11.513, dias_mae: 9.196, top_n: N/A, double run: True, bootstrap: True
#
# healthCode 9e40be90-7c38-4057-96e8-9854e59f0241 (50 of total 58) ------------------
# dataset size: 3, model: rf, ntrees: 60, sys_mae: 0.0, dias_mae: 0.0, top_n: floors; wo_calories; active_minutes; distance_walking; active_calories, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 10.594, dias_mae: 8.607, top_n: N/A, double run: True, bootstrap: True
# dataset size: 3, model: xgb, ntrees: 60, sys_mae: 0.0, dias_mae: 0.0, top_n: floors; wo_calories; active_minutes; distance_walking; active_calories, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 11.679, dias_mae: 9.567, top_n: N/A, double run: True, bootstrap: True
#
# healthCode cb9c3aa2-cca1-47d9-86de-552c702d6ad2 (51 of total 58) ------------------
# dataset size: 3, model: rf, ntrees: 60, sys_mae: 0.0, dias_mae: 0.0, top_n: floors; wo_calories; active_minutes; distance_walking; active_calories, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 10.527, dias_mae: 8.188, top_n: N/A, double run: True, bootstrap: True
# dataset size: 3, model: xgb, ntrees: 60, sys_mae: 0.0, dias_mae: 0.0, top_n: floors; wo_calories; active_minutes; distance_walking; active_calories, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 10.996, dias_mae: 8.674, top_n: N/A, double run: True, bootstrap: True
#
# healthCode 5d5c7761-5116-4c0f-8c7f-bdb6ffdec086 (52 of total 58) ------------------
# dataset size: 3, model: rf, ntrees: 60, sys_mae: 2.0, dias_mae: 2.0, top_n: wo_calories; distance_walking; steps; bed_time; awake_count, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 10.795, dias_mae: 8.317, top_n: N/A, double run: True, bootstrap: True
# dataset size: 3, model: xgb, ntrees: 60, sys_mae: 2.0, dias_mae: 6.0, top_n: distance_walking; floors; wo_calories; active_minutes; active_calories, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 11.076, dias_mae: 8.366, top_n: N/A, double run: True, bootstrap: True
#
# healthCode 670ce464-b660-4785-92af-1680ac804707 (53 of total 58) ------------------
# dataset size: 3, model: rf, ntrees: 60, sys_mae: 15.0, dias_mae: 2.0, top_n: bed_time; wo_calories; distance_walking; floors; active_calories, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 11.826, dias_mae: 9.312, top_n: N/A, double run: True, bootstrap: True
# dataset size: 3, model: xgb, ntrees: 60, sys_mae: 3.0, dias_mae: 0.0, top_n: distance_walking; floors; wo_calories; active_minutes; active_calories, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 10.915, dias_mae: 8.518, top_n: N/A, double run: True, bootstrap: True
#
# healthCode 20a301ff-647e-4989-8ee2-0091f5340b48 (54 of total 58) ------------------
# dataset size: 3, model: rf, ntrees: 60, sys_mae: 1.0, dias_mae: 4.0, top_n: floors; wo_calories; active_minutes; distance_walking; active_calories, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 10.29, dias_mae: 8.406, top_n: N/A, double run: True, bootstrap: True
# dataset size: 3, model: xgb, ntrees: 60, sys_mae: 7.0, dias_mae: 10.0, top_n: floors; wo_calories; active_minutes; distance_walking; active_calories, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 11.487, dias_mae: 9.188, top_n: N/A, double run: True, bootstrap: True
#
# healthCode 9ea35b43-2832-4dfa-9944-da6eacbd109e (55 of total 58) ------------------
# dataset size: 3, model: rf, ntrees: 60, sys_mae: 2.0, dias_mae: 6.0, top_n: steps; distance_walking; awake_count; wo_calories; bed_time, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 9.817, dias_mae: 7.906, top_n: N/A, double run: True, bootstrap: True
# dataset size: 3, model: xgb, ntrees: 60, sys_mae: 2.0, dias_mae: 9.0, top_n: distance_walking; floors; wo_calories; active_minutes; active_calories, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 11.728, dias_mae: 8.991, top_n: N/A, double run: True, bootstrap: True
#
# healthCode e29a4ba4-3997-4c31-8a57-190140d91907 (56 of total 58) ------------------
# dataset size: 3, model: rf, ntrees: 60, sys_mae: 2.0, dias_mae: 6.0, top_n: sleep_minutes; awake_count; steps; wo_calories; bed_time, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 11.379, dias_mae: 9.174, top_n: N/A, double run: True, bootstrap: True
# dataset size: 3, model: xgb, ntrees: 60, sys_mae: 0.0, dias_mae: 0.0, top_n: steps; floors; wo_calories; active_minutes; distance_walking, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 11.228, dias_mae: 8.817, top_n: N/A, double run: True, bootstrap: True
#
# healthCode 0988834f-995b-4878-bc37-5eb53cc408d3 (57 of total 58) ------------------
# dataset size: 3, model: rf, ntrees: 60, sys_mae: 5.0, dias_mae: 1.0, top_n: awake_count; floors; active_calories; steps; bed_time, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 10.54, dias_mae: 8.232, top_n: N/A, double run: True, bootstrap: True
# dataset size: 3, model: xgb, ntrees: 60, sys_mae: 0.0, dias_mae: 3.0, top_n: distance_walking; floors; wo_calories; active_minutes; active_calories, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 11.183, dias_mae: 9.013, top_n: N/A, double run: True, bootstrap: True
#
# healthCode 79211358-a1be-49a0-9d58-23deaaa9e954 (58 of total 58) ------------------
# dataset size: 4, model: rf, ntrees: 60, sys_mae: 6.0, dias_mae: 5.0, top_n: sleep_minutes; wo_calories; bed_time; distance_walking; steps, double run: False, bootstrap: True
# dataset size: 1120, model: rf, ntrees: 60, sys_mae: 11.147, dias_mae: 9.268, top_n: N/A, double run: True, bootstrap: True
# dataset size: 4, model: xgb, ntrees: 60, sys_mae: 0.0, dias_mae: 0.0, top_n: distance_walking; floors; wo_calories; active_minutes; active_calories, double run: False, bootstrap: True
# dataset size: 1120, model: xgb, ntrees: 60, sys_mae: 11.161, dias_mae: 8.777, top_n: N/A, double run: True, bootstrap: True
#
# --------------------------------------------------------------------------------

# %%
# OPTIONAL - ADD HISTORICAL BP - Add BP historical variable to master df (1 period, 2 periods, 3 periods)
'''
Here is where we list the historical BP values for each row in master_df:
select a period of k days. If k is more than 1, aggregate within the period via averaging
then a number of periods from [1, 2, 3]
periods should not overlap with each other

from augmentations import historical_BP

historical = historical_BP(baseline, 3)
historical
'''
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [7], line 10
#       2 '''
#       3 Here is where we list the historical BP values for each row in master_df:
#       4 select a period of k days. If k is more than 1, aggregate within the period via averaging
#       5 then a number of periods from [1, 2, 3]
#       6 periods should not overlap with each other
#       7 '''
#       8 from augmentations import historical_BP
# ---> 10 historical = historical_BP(baseline, 3)
#      11 historical
#
# File c:\Research\Hamphrey\bp-recommender\augmentations.py:34, in historical_BP(predictor, k)
#      31 predictor.sort_values(by=['healthCode', 'date'], inplace=True)
#      33 for col in ['systolic', 'diastolic']:
# ---> 34     data[col+'_'+k] = predictor.groupby('healthCode')[col].transform(lambda x: x.rolling(window=k, min_periods=1).mean())
#      36 return historical_BP
#
# TypeError: can only concatenate str (not "int") to str
